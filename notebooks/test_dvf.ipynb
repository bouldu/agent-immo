# %%
import os
import sys

sys.path.insert(0, os.path.abspath('..'))

# %load_ext autoreload
# %autoreload 2

from backend.utils.cadastre import geocode_address
from backend.utils.dvf import get_dvf_transactions
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ADRESSE = "10 rue de la Paix, 75002 Paris"
DISTANCE = 200

geocoding_result = await geocode_address(ADRESSE)
LAT = geocoding_result['latitude']
LON = geocoding_result['longitude']
print(f"Coordonnées: ({LAT}, {LON})")


dvf_result = await get_dvf_transactions(LAT, LON, dist=DISTANCE)
transactions = dvf_result['transactions']
print(f'Source: {dvf_result["source"]}')
print(f'Dernière mise à jour: {dvf_result["derniere_maj"]}')
print(f'Licence: {dvf_result["licence"]}')
print(f"Transactions trouvées: {len(transactions)}")
print(f'First transaction: {transactions[0]}')
# Out:
# Coordonnées: (48.868989, 2.33115)
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[8], line 10
#       6 LON = geocoding_result['longitude']
#       7 print(f"Coordonnées: ({LAT}, {LON})")
# ---> 10 dvf_result = await get_dvf_transactions(LAT, LON, dist=DISTANCE)
#      11 transactions = dvf_result['transactions']
#      12 print(f'Source: {dvf_result["source"]}')
#
# File c:\Users\Ben\PycharmProjects\agent-immo\backend\utils\dvf.py:27, in get_dvf_transactions(lat, lon, dist)
#       8 async def get_dvf_transactions(lat: float, lon: float, dist: int = 200) -> dict[str, Any]:
#       9     """
#      10     Get real estate transactions (DVF) data from coordinates using API CQuest DVF.
#      11
#      12     Args:
#      13         lat: Latitude (WGS84)
#      14         lon: Longitude (WGS84)
#      15         dist: Distance in meters around the point (default: 200)
# ...

# %% [markdown]
# for transaction in transactions[:10]:
#     print(f"{transaction.get('date_mutation')} - {transaction.get('adresse')}")
#     if transaction.get('valeur_fonciere'):
#         print(f"  Valeur: {transaction['valeur_fonciere']:,} €")
#     if transaction.get('surface_relle_bati'):
#         print(f"  Surface: {transaction['surface_relle_bati']} m²")
#     print()
